# %% [markdown]
# HAMOYE INTERNSHIP STAGE A

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use("ggplot")

# %%
# Importing dataset

food_data = pd.read_csv("FoodBalanceSheets_E_Africa_NOFLAG.csv")

# %%
# Checking the imported data

food_data.head(10)
# Out:
#    Area Code     Area  Item Code              Item  Element Code  \
# 0          4  Algeria       2501        Population           511
# 1          4  Algeria       2501        Population          5301
# 2          4  Algeria       2901       Grand Total           664
# 3          4  Algeria       2901       Grand Total           674
# 4          4  Algeria       2901       Grand Total           684
# 5          4  Algeria       2903  Vegetal Products           664
# 6          4  Algeria       2903  Vegetal Products           674
# 7          4  Algeria       2903  Vegetal Products           684
# 8          4  Algeria       2941   Animal Products           664
# 9          4  Algeria       2941   Animal Products           674
#
#                                   Element             Unit     Y2014  \
# 0           Total Population - Both sexes     1000 persons  38924.00
# 1                Domestic supply quantity      1000 tonnes      0.00
# ...

# %%
# Checing the shape(row and columns) of the data

food_data.shape
# Out:
# (60943, 12)

# %%
# Checking the data info

food_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60943 entries, 0 to 60942
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Area Code     60943 non-null  int64
#  1   Area          60943 non-null  object
#  2   Item Code     60943 non-null  int64
#  3   Item          60943 non-null  object
#  4   Element Code  60943 non-null  int64
#  5   Element       60943 non-null  object
#  6   Unit          60943 non-null  object
#  7   Y2014         59354 non-null  float64
#  8   Y2015         59395 non-null  float64
#  9   Y2016         59408 non-null  float64
#  10  Y2017         59437 non-null  float64
#  11  Y2018         59507 non-null  float64
# dtypes: float64(5), int64(3), object(4)
# memory usage: 5.6+ MB

# %%
# Checking for the presence of null values

food_data.isnull().sum()
# Out:
# Area Code          0
# Area               0
# Item Code          0
# Item               0
# Element Code       0
# Element            0
# Unit               0
# Y2014           1589
# Y2015           1548
# Y2016           1535
# Y2017           1506
# Y2018           1436
# dtype: int64

# %%
# Dropping the null values

food_data.dropna(axis = 0, how = "any", inplace =  True)

# %%
# Checking for duplicates

food_data.duplicated().any()
# Out:
# False

# %%
# Checking the dataset after dropping the null values

food_data.head()
# Out:
#    Area Code     Area  Item Code         Item  Element Code  \
# 0          4  Algeria       2501   Population           511
# 1          4  Algeria       2501   Population          5301
# 2          4  Algeria       2901  Grand Total           664
# 3          4  Algeria       2901  Grand Total           674
# 4          4  Algeria       2901  Grand Total           684
#
#                                   Element             Unit     Y2014  \
# 0           Total Population - Both sexes     1000 persons  38924.00
# 1                Domestic supply quantity      1000 tonnes      0.00
# 2           Food supply (kcal/capita/day)  kcal/capita/day   3377.00
# 3  Protein supply quantity (g/capita/day)     g/capita/day     94.90
# 4      Fat supply quantity (g/capita/day)     g/capita/day     80.06
#
#       Y2015     Y2016     Y2017     Y2018
# 0  39728.00  40551.00  41389.00  42228.00
# 1      0.00      0.00      0.00      0.00
# 2   3379.00   3372.00   3341.00   3322.00
# ...

# %%
# Checking the number of areas in the dataset

food_data["Area"].nunique()
# Out:
# 49

# %%
# Checking for the sum of all items in the areas

af_data = food_data.groupby("Area").sum()
af_data
# Out:
#                              Area Code  Item Code  Element Code       Y2014  \
# Area
# Algeria                           4976    3348772       4641561   313363.33
# Angola                            9450    3625712       5131258   208584.42
# Benin                            64236    3262559       4437226   118001.79
# Botswana                         26840    3611194       5076979    22339.92
# Burkina Faso                    312919    3605367       5086308   105036.33
# Cabo Verde                       40635    3133712       4218776    14576.94
# Cameroon                         45280    3797817       5420755   217595.28
# Central African Republic         45954    3337433       4533698    28735.02
# Chad                             48048    3315464       4591403    65938.17
# Comoros                           2025     124514        241681       32.00
# Congo                            61456    3588226       5015485    38694.26
# ...

# %%
# Checking the statistics of the dataset

food_data.describe()
# Out:
#           Area Code     Item Code  Element Code          Y2014          Y2015  \
# count  57784.000000  57784.000000  57784.000000   57784.000000   57784.000000
# mean     134.499342   2690.495656   3745.422868     137.831770     138.990488
# std       72.651212    146.625825   2217.914615    1588.660769    1625.441821
# min        4.000000   2501.000000    511.000000   -1796.000000   -3161.000000
# 25%       74.000000   2563.000000    674.000000       0.000000       0.000000
# 50%      136.000000   2633.000000   5142.000000       0.140000       0.130000
# 75%      196.000000   2781.000000   5301.000000       9.000000       9.000000
# max      276.000000   2961.000000   5911.000000  176405.000000  181137.000000
#
#                Y2016          Y2017          Y2018
# count   57784.000000   57784.000000   57784.000000
# mean      140.376380     144.927790     148.027664
# std      1662.732983    1695.436448    1735.920219
# min     -3225.000000   -1582.000000   -3396.000000
# ...

# %%
# Getting th Correlation of all columns in the dataset

food_data.corr()
# Out:
#               Area Code  Item Code  Element Code     Y2014     Y2015  \
# Area Code      1.000000  -0.005850      0.003624  0.006091  0.005267
# Item Code     -0.005850   1.000000     -0.016521  0.021102  0.020226
# Element Code   0.003624  -0.016521      1.000000  0.026257  0.025632
# Y2014          0.006091   0.021102      0.026257  1.000000  0.994647
# Y2015          0.005267   0.020226      0.025632  0.994647  1.000000
# Y2016          0.005246   0.019382      0.025080  0.996081  0.995738
# Y2017          0.004979   0.020812      0.025932  0.995229  0.988047
# Y2018          0.005571   0.020527      0.025989  0.994871  0.988207
#
#                  Y2016     Y2017     Y2018
# Area Code     0.005246  0.004979  0.005571
# Item Code     0.019382  0.020812  0.020527
# Element Code  0.025080  0.025932  0.025989
# Y2014         0.996081  0.995229  0.994871
# Y2015         0.995738  0.988047  0.988207
# Y2016         1.000000  0.992784  0.992756
# ...

# %%
# Checking the sum of all Elements in the dataset

food_data.groupby("Element").sum()
# Out:
#                                         Area Code  Item Code  Element Code  \
# Element
# Domestic supply quantity                   698435   13986139      27634113
# Export Quantity                            415968    7894703      17224654
# Fat supply quantity (g/capita/day)         662095   13289323       3370752
# Feed                                       144633    2933176       6012369
# Food                                       652391   13091136      25020972
# Food supply (kcal/capita/day)              659187   13227714       3256920
# Food supply quantity (kg/capita/yr)        647542   12991502       3115350
# Import Quantity                            621285   12533807      26102372
# Losses                                     274321    5422290      10286984
# Other uses (non-food)                      208464    4179786       7859850
# Processing                                 268111    5266227      10149118
# ...

# %%
# Checking for the sum of all items across the years

food_data.groupby("Item").sum()
# Out:
#                      Area Code  Item Code  Element Code      Y2014      Y2015  \
# Item
# Alcohol, Non-Food        35230     693999       1389590    2329.00    2119.00
# Alcoholic Beverages      73136    1616972       2110145  102391.11   98774.72
# Animal Products          18060     397035         90990   11935.65   11811.73
# Animal fats              83742    1847142       2497151  209460.54  200675.72
# Apples and products      67924    1321585       1849486    9499.23   10559.15
# ...                        ...        ...           ...        ...        ...
# Vegetables, Other        75817    1474430       2179992  155038.96  158104.08
# Vegetal Products         18060     391905         90990  107145.19  107064.17
# Wheat and products       85608    1607040       2583023  232670.13  234710.51
# Wine                     63806    1269090       1707019    4494.36    4250.81
# Yams                     39196     752895       1089374  200396.96  203150.78
#
# ...

# %%
# Getting the sum of each element in year 2018

food_data.groupby("Element").sum()["Y2018"]
# Out:
# Element
# Domestic supply quantity                  2161167.10
# Export Quantity                            181067.80
# Fat supply quantity (g/capita/day)          10257.21
# Feed                                       233441.68
# Food                                      1303806.28
# Food supply (kcal/capita/day)              455241.00
# Food supply quantity (kg/capita/yr)         49055.02
# Import Quantity                            287736.09
# Losses                                     163902.00
# Other uses (non-food)                       91273.97
# Processing                                 308421.00
# Production                                2075025.89
# Protein supply quantity (g/capita/day)      11833.43
# Residuals                                   34864.00
# Seed                                        25263.14
# Stock Variation                             20579.91
# Total Population - Both sexes             1140605.00
# Tourist consumption                            90.00
# ...

# %%
# Getting the data of the Area Algeria

food_data[food_data["Area"] == "Algeria"]
# Out:
#       Area Code     Area  Item Code           Item  Element Code  \
# 0             4  Algeria       2501     Population           511
# 1             4  Algeria       2501     Population          5301
# 2             4  Algeria       2901    Grand Total           664
# 3             4  Algeria       2901    Grand Total           674
# 4             4  Algeria       2901    Grand Total           684
# ...         ...      ...        ...            ...           ...
# 1308          4  Algeria       2899  Miscellaneous          5142
# 1309          4  Algeria       2899  Miscellaneous           645
# 1310          4  Algeria       2899  Miscellaneous           664
# 1311          4  Algeria       2899  Miscellaneous           674
# 1312          4  Algeria       2899  Miscellaneous           684
#
#                                      Element             Unit     Y2014  \
# 0              Total Population - Both sexes     1000 persons  38924.00
# ...

# %%
# Total count of all elements in the different areas.

food_data.groupby("Area")["Element"].count()
# Out:
# Area
# Algeria                        1244
# Angola                         1350
# Benin                          1212
# Botswana                       1342
# Burkina Faso                   1343
# Cabo Verde                     1161
# Cameroon                       1415
# Central African Republic       1242
# Chad                           1232
# Comoros                          45
# Congo                          1336
# C�te d'Ivoire                  1431
# Djibouti                       1021
# Egypt                          1437
# Eswatini                       1206
# Ethiopia                       1390
# Ethiopia PDR                     39
# Gabon                          1166
# Gambia                         1066
# Ghana                          1311
# Guinea                         1323
# Guinea-Bissau                   992
# Kenya                          1521
# Lesotho                        1053
# Liberia                        1070
# Madagascar                     1405
# ...

# %%
# Checking for the element "Import Quantity" across different areas

import_Q = food_data[food_data["Element"] == "Import Quantity"]
import_Q
# Out:
#        Area Code      Area  Item Code                      Item  Element Code  \
# 12             4   Algeria       2905  Cereals - Excluding Beer          5611
# 28             4   Algeria       2511        Wheat and products          5611
# 44             4   Algeria       2805         Rice and products          5611
# 59             4   Algeria       2513       Barley and products          5611
# 74             4   Algeria       2514        Maize and products          5611
# ...          ...       ...        ...                       ...           ...
# 60897        181  Zimbabwe       2769   Aquatic Animals, Others          5611
# 60905        181  Zimbabwe       2775            Aquatic Plants          5611
# 60913        181  Zimbabwe       2928             Miscellaneous          5611
# 60923        181  Zimbabwe       2680               Infant food          5611
# 60933        181  Zimbabwe       2899             Miscellaneous          5611
#
# ...

# %%
# Getting the sum of the element "Import Quantity" in each Area.

grouped_IQ = pd.DataFrame(import_Q.groupby(import_Q["Area"])["Y2018"].sum())

grouped_IQ
# Out:
#                                 Y2018
# Area
# Algeria                      36238.29
# Angola                        7769.67
# Benin                         7008.24
# Botswana                      1908.42
# Burkina Faso                  2601.64
# Cabo Verde                     499.66
# Cameroon                      4188.88
# Central African Republic        75.02
# Chad                           491.95
# Comoros                          2.92
# Congo                         1785.27
# C�te d'Ivoire                 9271.21
# Djibouti                      3784.92
# Egypt                        53951.20
# Eswatini                       936.53
# Ethiopia                      5655.24
# Ethiopia PDR                     0.00
# Gabon                         1079.75
# Gambia                        1212.10
# Ghana                         9849.68
# Guinea                        4707.95
# Guinea-Bissau                  497.72
# Kenya                        11104.96
# ...
